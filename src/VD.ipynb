# %% [markdown]
# ### Import

# %%
import pandas as pd

# %%
# %run utils/Visualisation.py

# %% [markdown]
# Real Data

# %%
RD = pd.read_csv('../data/real_data/d1.csv')

# %%
len(RD)
# Out:
# 10000

# %% [markdown]
# Synthetic Data

# %%
SD_HMA = pd.read_csv('../data/synthetic_data/FAST_ML_d1.csv')

# %%
len(SD_HMA)

# %%
SD_FAST_ML = pd.read_csv('../data/synthetic_data/FAST_ML_d1.csv')

# %%
len(SD_FAST_ML)
# Out:
# 200000

# %% [markdown]
# ### Visualization

# %%
# Region VS Balance dependency replication
plot_dependency_region_balance(RD, SD_HMA)

# %%
# Region VS Balance dependency replication
plot_dependency_region_balance(RD, SD_FAST_ML)

# %%
# Employment_Type VS Balance dependency replication
for et in RD['Employment_Type'].unique():
    plot_dependency_employement_type_balance(RD, SD, et)
