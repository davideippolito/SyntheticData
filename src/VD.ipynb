# %% [markdown]
# # Visualise Datasets

# %% [markdown]
# ### Import

# %%
import pandas as pd

# %% [markdown]
# External Functions

# %%
# %run utils/Visualisation.py

# %% [markdown]
# Data Paths

# %%
# Real Dataset Output
path_RD = '../data/real_data/REF.csv'

# Metadata based on Real Dataset Output
path_metadata_st = '../data/metadata/metadata_st_REF.json'
path_metadata_mt = '../data/metadata/metadata_mt_REF.json'

# Synthetic Dataset Output from HMA model
path_FAST_ML = '../data/synthetic_data/FAST_ML_test.csv'
path_CTGAN = '../data/synthetic_data/CTGAN_test.csv'
path_HMA = '../data/synthetic_data/HMA_test.csv'

# %% [markdown]
# Real Data

# %%
RD = pd.read_csv(path_RD)

# %% [markdown]
# Synthetic Data

# %%
SD_FAST_ML = pd.read_csv(path_FAST_ML)
SD_CTGAN = pd.read_csv(path_CTGAN)
SD_HMA = pd.read_csv(path_HMA)

# %% [markdown]
# ### Visualization

# %%
# Create a dictionary with the dataframes
dataframes = {
    'RD': RD,
    'SD_HMA': SD_HMA,
    # 'SD_CTGAN': SD_CTGAN,
    'SD_FAST_ML': SD_FAST_ML
}

# Region VS Balance dependency replication
plot_dependency_region_balance(dataframes)

# %%
# Create a list with the dataframes
dataframes = [
    RD, 
    SD_HMA,
    # SD_CTGAN,
    SD_FAST_ML
]

# Employment_type VS Balance dependency replication
employment_types = RD['Employment_Type'].unique()

plot_dependency_employment_type_balance(dataframes, employment_types)

# %% [markdown]
# ### REF VS Test

# %%
# Create a list with the dataframes
dataframes = [
    RD, 
    SD_HMA,
    # SD_CTGAN,
    SD_FAST_ML
]

plot_kernel_density(dataframes, "Balance")

# %%
plot_kernel_density(dataframes, "Credit_Score")

# %%
plot_kernel_density(dataframes, "Interest_Rate")

# %%
plot_kernel_density(dataframes, "Tot_Transaction_Amount")

# %%
plot_kernel_density(dataframes, "Tot_Transaction_Amount")
