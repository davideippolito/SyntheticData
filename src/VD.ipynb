# %% [markdown]
# # Visualise Datasets

# %% [markdown]
# ### Import

# %%
import pandas as pd

# %% [markdown]
# External Functions

# %%
# %run utils/Visualisation.py

# %% [markdown]
# Data Paths

# %%
# Real Dataset Output
path_RD = '../data/real_data/d_c.csv'

# Metadata based on Real Dataset Output
path_metadata_st = '../data/metadata/metadata_st_d_c.json'
path_metadata_mt = '../data/metadata/metadata_mt_d_c.json'

# Synthetic Dataset Output from HMA model
path_HMA = '../data/synthetic_data/HMA_d_c.csv'
path_CTGAN = '../data/synthetic_data/CTGAN_d_c.csv'
path_FAST_ML = '../data/synthetic_data/FAST_ML_d_c.csv'

# %% [markdown]
# Real Data

# %%
RD = pd.read_csv(path_RD)
len(RD)
# Out:
# 1000

# %% [markdown]
# Synthetic Data

# %%
SD_HMA = pd.read_csv(path_HMA)
len(SD_HMA)
# Out:
# 1000

# %%
# CTGAN = pd.read_csv(path_CTGAN_d_c)
# len(CTGAN)

# %%
SD_FAST_ML = pd.read_csv(path_FAST_ML)
len(SD_FAST_ML)
# Out:
# 1000

# %% [markdown]
# ### Visualization

# %%
# Create a dictionary with the dataframes
dataframes = {
    'RD': RD,
    'SD_HMA': SD_HMA,
#    'SD_CTGAN': CTGAN,
    'SD_FAST_ML': SD_FAST_ML
}

# Region VS Balance dependency replication
plot_dependency_region_balance(dataframes)

# %%
# Create a list with the dataframes
dataframes = [
    RD, 
    SD_HMA,
#    'SD_CTGAN': CTGAN,
#    SD_FAST_ML
]

dataframe_names = [df_name for df_name in dataframes]

# Employment_type VS Balance dependency replication
employment_types = RD['Employment_Type'].unique()

plot_dependency_employment_type_balance(dataframes, employment_types)
